# %%
from matplotlib import pyplot as plt
# %matplotlib inline
from importlib import reload
from utils import *
# Out:
# C:\Users\Alekseyl\Envs\absa\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
from jupyterthemes import jtplot
# jtplot.style()  # development
jtplot.reset()  # production

# %%
w2v = load_w2v()
# Out:
# Loading real w2v...
# Done

# %%
import ote
reload(ote)
ote_ = ote.OTE(w2v)
ote_.grid_search(ote_.get_ote_features, np.linspace(0.1, 3, 20))
# Out:
# Loading tokenizer...
# Loading dataset...
# Fitting...
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  4.5min finished
#            C   Mean F1
# 0   0.100000  0.450530
# 1   0.252632  0.450530
# 2   0.405263  0.444184
# 3   0.557895  0.444184
# 4   0.710526  0.444184
# 5   0.863158  0.444184
# 6   1.015789  0.555230
# 7   1.168421  0.450530
# 8   1.321053  0.488603
# 9   1.473684  0.488603
# 10  1.626316  0.505524
# 11  1.778947  0.505524
# 12  1.931579  0.444184
# 13  2.084211  0.450530
# 14  2.236842  0.431493
# 15  2.389474  0.543597
# 16  2.542105  0.456189
# 17  2.694737  0.505524
# 18  2.847368  0.431493
# 19  3.000000  0.431493
# Test score: 0.7499999999999999

# %%
ote_.grid_search(ote_.get_ote_features_window, np.concatenate([
                np.array([0.0001, 0.001, 0.01, 0.1, 0.5]),
                np.linspace(1, 10, 10)]))
# Out:
# Loading dataset...
# Fitting...
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  3.3min finished
#           C   Mean F1
# 0    0.0001  0.000000
# 1    0.0010  0.331696
# 2    0.0100  0.454862
# 3    0.1000  0.376499
# 4    0.5000  0.481200
# 5    1.0000  0.444184
# 6    2.0000  0.543597
# 7    3.0000  0.431493
# 8    4.0000  0.431493
# 9    5.0000  0.543597
# 10   6.0000  0.431493
# 11   7.0000  0.505524
# 12   8.0000  0.469566
# 13   9.0000  0.505524
# 14  10.0000  0.524560
# Test score: 0.7692307692307692
